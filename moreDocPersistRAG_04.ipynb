# %%
import os 
from dotenv import load_dotenv 
load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-nano",temperature=0)

# %%
#RAG Implementation using PDF (extracting text from PDFs)

from langchain_community.document_loaders import PyPDFLoader

pdf_path = "./Docs/fabric-admin.pdf"

loader = PyPDFLoader(pdf_path)
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'Microsoft Learn PDF 1.0.25309.01', 'creator': 'Microsoft Learn', 'creationdate': '2025-12-09T19:42:08+00:00', 'title': 'fabric admin | Microsoft Learn', 'moddate': '2025-12-09T19:42:08+00:00', 'source': './Docs/fabric-admin.pdf', 'total_pages': 290, 'page': 0, 'page_label': '1'}, page_content='Tell us about your PDF experience.\nMicrosoft Fabric documentation for\nadmins\nLearn about the Microsoft Fabric admin settings, options, and tools.\nFabric in your organization\nｅOVERVIEW\nWhat is Microsoft Fabric admin?\nWhat is the admin portal?\nｂGET STARTED\nEnable Fabric for your organization\nRegion availability\nFind your Fabric home region\nｃHOW-TO GUIDE\nUnderstand Fabric admin roles\nｉREFERENCE\nGovernance documentation\nSecurity documentation\nTools and settings\nｅOVERVIEW\nAbout tenant settings\nｃHOW-TO GUIDE\nSet up git integration\nSet up item certification'),
# ...

# %%
#chunking 
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 100
)

chunks = splitter.split_documents(docs)
chunks
# Out:
# [Document(metadata={'producer': 'Microsoft Learn PDF 1.0.25309.01', 'creator': 'Microsoft Learn', 'creationdate': '2025-12-09T19:42:08+00:00', 'title': 'fabric admin | Microsoft Learn', 'moddate': '2025-12-09T19:42:08+00:00', 'source': './Docs/fabric-admin.pdf', 'total_pages': 290, 'page': 0, 'page_label': '1'}, page_content='Tell us about your PDF experience.\nMicrosoft Fabric documentation for\nadmins\nLearn about the Microsoft Fabric admin settings, options, and tools.\nFabric in your organization\nｅOVERVIEW\nWhat is Microsoft Fabric admin?\nWhat is the admin portal?\nｂGET STARTED\nEnable Fabric for your organization\nRegion availability\nFind your Fabric home region\nｃHOW-TO GUIDE\nUnderstand Fabric admin roles\nｉREFERENCE\nGovernance documentation\nSecurity documentation\nTools and settings\nｅOVERVIEW\nAbout tenant settings\nｃHOW-TO GUIDE\nSet up git integration\nSet up item certification'),
# ...

# %%
len(chunks)
# Out:
# 652

# %%
#Embedding 

from langchain_community.vectorstores import Chroma 
from langchain_openai import OpenAIEmbeddings

embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

vectorstore = Chroma(persist_directory="./VectorDB/",
                     embedding_function=embedding_model)
# Out:
# /var/folders/45/c_9kf7kx6yx0mfymxgmz4ljr0000gn/T/ipykernel_13633/1596716465.py:8: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vectorstore = Chroma(persist_directory="./VectorDB/",

# %%
vectorstore.add_documents(chunks)
# Out:
# ['b8e99ced-de01-4d9f-b6eb-251df0da39e4',
#  '1f894436-d497-4824-88f9-d77f7b878032',
#  'b4f2e201-ce54-4eca-b387-b4747fa33b6d',
#  'b51886ba-2a64-4099-b9b9-f3d65294c8ae',
#  '8d1e47ee-0d1a-417e-902e-6993338cbd82',
#  '5a289441-6cfc-4ff8-8cf8-82ed1a04fe39',
#  '91c8d9e2-9578-4b3c-b570-9c3a2e894508',
#  '4fa9842e-22ac-49e3-8b10-9ce4e732f538',
#  '43a45a70-affa-4ce9-b547-271325aef9e7',
#  '43028d18-5b8d-4ad0-84a9-bd456d5280f6',
#  '7fce5463-1e03-4b0a-b0f1-228152e51fc4',
#  '083098f3-d7e2-4656-b36e-156010262210',
#  '3265aada-cf5d-41ea-89b8-65e1337526bb',
#  '25538f24-b30a-4eb0-b877-507fb1e2290b',
#  'ab6e349b-9979-46d5-aa8e-9b6e1e7c10ad',
#  'c6aaa845-cfdf-45c2-9db9-318a6910ce50',
#  'd2ae452f-004b-46cd-b061-2fccaee34370',
#  '3fc2ecf5-d4db-4ec6-a01d-1bd2c0c830aa',
#  'c702429e-76af-4e1d-875b-fa74d359d9e4',
#  '87a22dee-58e0-4e5b-97fb-158968bac7c1',
#  '1706b0e9-a4c6-41f2-9cfc-5e74af2ff0bf',
#  'f7327bc5-fcdb-4eb1-afec-ed8d4a0ac827',
#  '0e10c5f5-f5df-4c74-b366-3d61eb8f86b6',
# ...

# %%
chunks[0].metadata
# Out:
# {'producer': 'Microsoft Learn PDF 1.0.25309.01',
#  'creator': 'Microsoft Learn',
#  'creationdate': '2025-12-12T17:01:10+00:00',
#  'title': 'fabric onelake | Microsoft Learn',
#  'moddate': '2025-12-12T17:01:10+00:00',
#  'source': './Docs/fabric-onelake.pdf',
#  'total_pages': 382,
#  'page': 0,
#  'page_label': '1'}

# %%
vectorstore.similarity_search("why do we need onelake?",k=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 vectorstore.similarity_search("why do we need onelake?",k=3)
#
# NameError: name 'vectorstore' is not defined

# %%
#Reusing the vectorDB

vectorstore_persist = Chroma(
    persist_directory="./VectorDB",
    embedding_function = embedding_model
)

# %%
vectorstore_persist.similarity_search("why do we need OneLake?",k=3)
# Out:
# [Document(metadata={'title': 'fabric onelake | Microsoft Learn', 'page': 2, 'moddate': '2025-12-12T17:01:10+00:00', 'producer': 'Microsoft Learn PDF 1.0.25309.01', 'creator': 'Microsoft Learn', 'creationdate': '2025-12-12T17:01:10+00:00', 'page_label': '3', 'source': './Docs/fabric-onelake.pdf', 'total_pages': 382}, page_content='OneLake, the OneDrive for data\nArticle• 07/25/2024\nOneLake is a single, unified, logical data lake for your whole organization. A data Lake\nprocesses large volumes of data from various sources. Like OneDrive, OneLake comes\nautomatically with every Microsoft Fabric tenant and is designed to be the single place\nfor all your analytics data. OneLake brings customers:\nOne data lake for the entire organization\nOne copy of data for use with multiple analytical engines\nBefore OneLake, it was easier for customers to create multiple lakes for different\nbusiness groups rather than collaborating on a single lake, even with the extra overhead\nof managing multip
# ...

# %%
vectorstore.similarity_search("what is Mircosoft Fabric admin?",k=3)
# Out:
# [Document(metadata={'page_label': '9', 'page': 8, 'producer': 'Microsoft Learn PDF 1.0.25309.01', 'moddate': '2025-12-09T19:42:08+00:00', 'total_pages': 290, 'source': './Docs/fabric-admin.pdf', 'creator': 'Microsoft Learn', 'creationdate': '2025-12-09T19:42:08+00:00', 'title': 'fabric admin | Microsoft Learn'}, page_content='What is Microsoft Fabric admin?\n07/01/2024\nMicrosoft Fabric admin is the management of the organization-wide settings that control how\nMicrosoft Fabric works. Users that are assigned to admin roles configure, monitor, and\nprovision organizational resources. This article provides an overview of admin roles, tasks, and\ntools to help you get started.\nThere are several roles that work together to administer Microsoft Fabric for your organization.\nMost admin roles are assigned in the Microsoft 365 admin portal or by using PowerShell. The\ncapacity admin roles are assigned when the capacity is created. To learn more about each of\nthe admin roles, see About adm
# ...
